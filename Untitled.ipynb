# %%
subs = ['sub-01_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-10_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-16_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-01_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-06_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-11_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-17_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-02_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-07_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-12_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-18_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-03_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-08_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-14_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-19_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-04_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-09_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-15_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-16_',
'sub-20_',
'sub-05_',
'sub-10_',
'sub-16_',]

# %%
len(set(subs))
# Out:
# 19
